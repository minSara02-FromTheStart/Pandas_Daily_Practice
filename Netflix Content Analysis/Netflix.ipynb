# %%
#What does our dataset look like?
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("NetflixData.csv")

#print("(rows,columns): ", df.shape)
#print("Columns : ", df.columns)
#print("Data Types: ", type(df))

print("Data Info: ", df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         60 non-null     str
#  1   type          60 non-null     str
#  2   genre         60 non-null     str
#  3   country       60 non-null     str
#  4   release_year  60 non-null     int64
#  5   rating        60 non-null     str
# dtypes: int64(1), str(5)
# memory usage: 2.9 KB
# Data Info:  None

# %%
#Is Netflix content mostly Movies or TV Shows?
type_count = df["type"].value_counts()
print("What type of content dominates the platform?")
print("Ans : ")
print(type_count)
# Out:
# What type of content dominates the platform?
# Ans :
# type
# Movie          32
# TV Show        22
# Documentary     6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,2))
type_count.plot(kind="bar")
plt.title("Movie Vs Tv Shows")
plt.xlabel("Content Type")
plt.ylabel("Content Number")

plt.show()

# %%
plt.figure()
plt.title("Movie,TV Show & Documentary Distribution")
type_count.plot(kind="pie",autopct="%1.1f%%", startangle=90,figsize=(3,2))
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
#Which genre appears the most?
